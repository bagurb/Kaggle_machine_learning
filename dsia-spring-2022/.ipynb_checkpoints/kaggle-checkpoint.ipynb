# %% [markdown]
# # IMPORT

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Data featuring
#
#
# Traitement de donnée

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
datas = pd.concat([train,test])

# %% [markdown]
# - Drop du StudentID (irrelevent dans notre cas)
# - Encoding Target
# - Missing values : 1328 Target (normal car base de test)

# %%
train.drop(columns="StudentId",inplace=True)

# %%
label_enco = LabelEncoder()
label_target = label_enco.fit_transform(train['Target'])
print(label_target)
# 0 = Dropout , 1 = Enrolled, 2 = Graduate
# Out:
# [0 2 2 ... 1 0 2]

# %%
train.drop(columns="Target",axis=1,inplace=True)
train["Target"] = label_target

# %%
total = train.isnull().sum().sort_values(ascending=False)

# show
pd.DataFrame(data={'Missing': total}).head(37)
# Out:
#                                                 Missing
# Marital status                                        0
# Age at enrollment                                     0
# Curricular units 1st sem (credited)                   0
# Curricular units 1st sem (enrolled)                   0
# Curricular units 1st sem (evaluations)                0
# Curricular units 1st sem (approved)                   0
# Curricular units 1st sem (grade)                      0
# Curricular units 1st sem (without evaluations)        0
# Curricular units 2nd sem (credited)                   0
# Curricular units 2nd sem (enrolled)                   0
# Curricular units 2nd sem (evaluations)                0
# Curricular units 2nd sem (approved)                   0
# Curricular units 2nd sem (grade)                      0
# Curricular units 2nd sem (without evaluations)        0
# Unemployment rate                                     0
# Inflation rate                                        0
# GDP                                                   0
# International                                         0
# Scholarship holder                                    0
# Application mode                                      0
# Gender                                                0
# Application order                                     0
# Course                                                0
# Daytime/evening attendance\t                          0
# Previous qualification                                0
# Previous qualification (grade)                        0
# Nationality                                           0
# Mother's qualification                                0
# Father's qualification                                0
# Mother's occupation                                   0
# Father's occupation                                   0
# Admission grade                                       0
# Displaced                                             0
# Educational special needs                             0
# Debtor                                                0
# Tuition fees up to date                               0
# Target                                                0

# %% [markdown]
# ## Correlation Matrix
#
# General corr matrix

# %%
train_corrmat = train.corr()
print(train_corrmat)
# Out:
#                                                 Marital status  \
# Marital status                                        1.000000
# Application mode                                      0.283230
# Application order                                    -0.131919
# Course                                                0.048351
# Daytime/evening attendance\t                         -0.283691
# Previous qualification                                0.058700
# Previous qualification (grade)                       -0.023628
# Nationality                                          -0.001862
# Mother's qualification                                0.189513
# Father's qualification                                0.130368
# Mother's occupation                                   0.020810
# Father's occupation                                   0.019992
# Admission grade                                       0.013980
# Displaced                                            -0.257573
# Educational special needs                            -0.028056
# Debtor                                                0.049945
# Tuition fees up to date                              -0.100831
# Gender                                               -0.017747
# Scholarship holder                                   -0.040105
# Age at enrollment                                     0.532665
# International                                        -0.024000
# Curricular units 1st sem (credited)                   0.078511
# Curricular units 1st sem (enrolled)                   0.062453
# Curricular units 1st sem (evaluations)                0.076519
# Curricular units 1st sem (approved)                  -0.017381
# Curricular units 1st sem (grade)                     -0.052265
# Curricular units 1st sem (without evaluations)        0.030305
# Curricular units 2nd sem (credited)                   0.084395
# Curricular units 2nd sem (enrolled)                   0.051795
# Curricular units 2nd sem (evaluations)                0.035497
# Curricular units 2nd sem (approved)                  -0.030361
# Curricular units 2nd sem (grade)                     -0.063332
# Curricular units 2nd sem (without evaluations)        0.027758
# Unemployment rate                                    -0.027686
# Inflation rate                                        0.004827
# GDP                                                  -0.012190
# Target                                               -0.087741
#
#                                                 Application mode  \
# Marital status                                          0.283230
# Application mode                                        1.000000
# Application order                                      -0.292673
# Course                                                  0.079521
# Daytime/evening attendance\t                           -0.319805
# Previous qualification                                  0.405754
# Previous qualification (grade)                         -0.038946
# Nationality                                             0.005355
# Mother's qualification                                  0.122954
# Father's qualification                                  0.077041
# Mother's occupation                                     0.047003
# Father's occupation                                     0.030487
# Admission grade                                        -0.010130
# Displaced                                              -0.307273
# Educational special needs                              -0.025684
# Debtor                                                  0.131367
# Tuition fees up to date                                -0.132501
# Gender                                                  0.147694
# Scholarship holder                                     -0.160093
# Age at enrollment                                       0.525378
# International                                           0.015857
# Curricular units 1st sem (credited)                     0.248693
# Curricular units 1st sem (enrolled)                     0.166140
# Curricular units 1st sem (evaluations)                  0.225214
# Curricular units 1st sem (approved)                    -0.022315
# Curricular units 1st sem (grade)                       -0.111502
# Curricular units 1st sem (without evaluations)          0.027480
# Curricular units 2nd sem (credited)                     0.243542
# Curricular units 2nd sem (enrolled)                     0.132125
# Curricular units 2nd sem (evaluations)                  0.165229
# Curricular units 2nd sem (approved)                    -0.059697
# Curricular units 2nd sem (grade)                       -0.114381
# Curricular units 2nd sem (without evaluations)          0.037492
# Unemployment rate                                       0.075775
# Inflation rate                                         -0.020523
# GDP                                                    -0.015862
# Target                                                 -0.209867
#
#                                                 Application order    Course  \
# Marital status                                          -0.131919  0.048351
# Application mode                                        -0.292673  0.079521
# Application order                                        1.000000  0.053368
# Course                                                   0.053368  1.000000
# Daytime/evening attendance\t                             0.160254 -0.051915
# Previous qualification                                  -0.175788  0.020111
# Previous qualification (grade)                          -0.070512 -0.075150
# Nationality                                             -0.023103 -0.023640
# Mother's qualification                                  -0.061478  0.056952
# Father's qualification                                  -0.052621  0.061807
# Mother's occupation                                     -0.036004  0.031862
# Father's occupation                                     -0.025619  0.025954
# Admission grade                                         -0.100283 -0.125786
# Displaced                                                0.319261 -0.093067
# Educational special needs                                0.040676  0.002463
# Debtor                                                  -0.058979 -0.028217
# Tuition fees up to date                                  0.045158  0.012743
# Gender                                                  -0.073786 -0.107462
# Scholarship holder                                       0.068781  0.024820
# Age at enrollment                                       -0.276837  0.048479
# International                                           -0.031540 -0.027366
# Curricular units 1st sem (credited)                     -0.136740 -0.093657
# Curricular units 1st sem (enrolled)                     -0.016959  0.332667
# Curricular units 1st sem (evaluations)                  -0.095608  0.279488
# Curricular units 1st sem (approved)                      0.030311  0.178871
# Curricular units 1st sem (grade)                         0.046917  0.384592
# Curricular units 1st sem (without evaluations)          -0.037994  0.035110
# Curricular units 2nd sem (credited)                     -0.131017 -0.078812
# Curricular units 2nd sem (enrolled)                      0.028622  0.410487
# Curricular units 2nd sem (evaluations)                  -0.052013  0.283521
# Curricular units 2nd sem (approved)                      0.062975  0.197997
# Curricular units 2nd sem (grade)                         0.050573  0.342332
# Curricular units 2nd sem (without evaluations)          -0.020588  0.035514
# Unemployment rate                                       -0.080164  0.018721
# Inflation rate                                          -0.007269  0.008311
# GDP                                                      0.019101 -0.041427
# Target                                                   0.088745  0.020586
#
#                                                 Daytime/evening attendance\t  \
# Marital status                                                     -0.283691
# Application mode                                                   -0.319805
# Application order                                                   0.160254
# Course                                                             -0.051915
# Daytime/evening attendance\t                                        1.000000
# Previous qualification                                             -0.083190
# Previous qualification (grade)                                      0.064687
# Nationality                                                         0.018417
# Mother's qualification                                             -0.208087
# Father's qualification                                             -0.147160
# Mother's occupation                                                -0.012926
# Father's occupation                                                -0.012775
# Admission grade                                                     0.021794
# Displaced                                                           0.275476
# Educational special needs                                           0.031136
# Debtor                                                              0.007025
# Tuition fees up to date                                             0.048453
# Gender                                                             -0.008525
# Scholarship holder                                                  0.098427
# Age at enrollment                                                  -0.473705
# International                                                       0.032900
# Curricular units 1st sem (credited)                                -0.143796
# Curricular units 1st sem (enrolled)                                -0.044724
# Curricular units 1st sem (evaluations)                             -0.049388
# Curricular units 1st sem (approved)                                 0.010498
# Curricular units 1st sem (grade)                                    0.059654
# Curricular units 1st sem (without evaluations)                      0.054574
# Curricular units 2nd sem (credited)                                -0.122959
# Curricular units 2nd sem (enrolled)                                 0.002892
# Curricular units 2nd sem (evaluations)                              0.016528
# Curricular units 2nd sem (approved)                                 0.031481
# Curricular units 2nd sem (grade)                                    0.050043
# Curricular units 2nd sem (without evaluations)                     -0.020200
# Unemployment rate                                                   0.050563
# Inflation rate                                                     -0.029515
# GDP                                                                 0.016956
# Target                                                              0.087208
#
#                                                 Previous qualification  \
# Marital status                                                0.058700
# Application mode                                              0.405754
# Application order                                            -0.175788
# Course                                                        0.020111
# Daytime/evening attendance\t                                 -0.083190
# Previous qualification                                        1.000000
# Previous qualification (grade)                                0.109517
# Nationality                                                  -0.031361
# Mother's qualification                                       -0.022877
# Father's qualification                                       -0.009386
# Mother's occupation                                          -0.003333
# Father's occupation                                           0.003434
# Admission grade                                               0.180762
# Displaced                                                    -0.117233
# Educational special needs                                    -0.009109
# Debtor                                                        0.102825
# Tuition fees up to date                                      -0.070901
# Gender                                                        0.053739
# Scholarship holder                                           -0.071629
# Age at enrollment                                             0.152333
# International                                                -0.030066
# Curricular units 1st sem (credited)                           0.183325
# Curricular units 1st sem (enrolled)                           0.094886
# Curricular units 1st sem (evaluations)                        0.138905
# Curricular units 1st sem (approved)                           0.041144
# Curricular units 1st sem (grade)                              0.003615
# Curricular units 1st sem (without evaluations)                0.001580
# Curricular units 2nd sem (credited)                           0.160649
# Curricular units 2nd sem (enrolled)                           0.071322
# Curricular units 2nd sem (evaluations)                        0.117448
# Curricular units 2nd sem (approved)                           0.011343
# Curricular units 2nd sem (grade)                              0.004724
# Curricular units 2nd sem (without evaluations)               -0.003203
# Unemployment rate                                             0.101522
# Inflation rate                                               -0.055605
# GDP                                                           0.072228
# Target                                                       -0.053785
#
#                                                 Previous qualification (grade)  \
# Marital status                                                       -0.023628
# Application mode                                                     -0.038946
# Application order                                                    -0.070512
# Course                                                               -0.075150
# Daytime/evening attendance\t                                          0.064687
# Previous qualification                                                0.109517
# Previous qualification (grade)                                        1.000000
# Nationality                                                           0.057115
# Mother's qualification                                               -0.066329
# Father's qualification                                               -0.031867
# Mother's occupation                                                  -0.020712
# Father's occupation                                                  -0.027678
# Admission grade                                                       0.559710
# Displaced                                                            -0.025079
# Educational special needs                                            -0.006554
# Debtor                                                               -0.032763
# Tuition fees up to date                                               0.057420
# Gender                                                               -0.059012
# Scholarship holder                                                    0.061022
# Age at enrollment                                                    -0.117555
# International                                                         0.058915
# Curricular units 1st sem (credited)                                  -0.017759
# Curricular units 1st sem (enrolled)                                  -0.024195
# Curricular units 1st sem (evaluations)                               -0.075075
# Curricular units 1st sem (approved)                                   0.054672
# Curricular units 1st sem (grade)                                      0.070258
# Curricular units 1st sem (without evaluations)                       -0.006451
# Curricular units 2nd sem (credited)                                  -0.026858
# Curricular units 2nd sem (enrolled)                                  -0.022924
# Curricular units 2nd sem (evaluations)                               -0.072581
# Curricular units 2nd sem (approved)                                   0.053421
# Curricular units 2nd sem (grade)                                      0.059821
# Curricular units 2nd sem (without evaluations)                       -0.020381
# Unemployment rate                                                     0.040532
# Inflation rate                                                        0.017046
# GDP                                                                  -0.048740
# Target                                                                0.111464
#
#                                                 Nationality  \
# Marital status                                    -0.001862
# Application mode                                   0.005355
# Application order                                 -0.023103
# Course                                            -0.023640
# Daytime/evening attendance\t                       0.018417
# Previous qualification                            -0.031361
# Previous qualification (grade)                     0.057115
# Nationality                                        1.000000
# Mother's qualification                            -0.056017
# Father's qualification                            -0.093294
# Mother's occupation                                0.017785
# Father's occupation                                0.010351
# Admission grade                                    0.034516
# Displaced                                         -0.010138
# Educational special needs                         -0.003516
# Debtor                                             0.061910
# Tuition fees up to date                           -0.029717
# Gender                                            -0.024003
# Scholarship holder                                -0.020476
# Age at enrollment                                  0.003872
# International                                      0.790818
# Curricular units 1st sem (credited)                0.002695
# Curricular units 1st sem (enrolled)               -0.006745
# Curricular units 1st sem (evaluations)            -0.018360
# Curricular units 1st sem (approved)                0.003991
# Curricular units 1st sem (grade)                   0.006637
# Curricular units 1st sem (without evaluations)     0.019019
# Curricular units 2nd sem (credited)               -0.004215
# Curricular units 2nd sem (enrolled)               -0.008834
# Curricular units 2nd sem (evaluations)            -0.026081
# Curricular units 2nd sem (approved)               -0.011743
# Curricular units 2nd sem (grade)                   0.003051
# Curricular units 2nd sem (without evaluations)    -0.011046
# Unemployment rate                                  0.001012
# Inflation rate                                    -0.008991
# GDP                                                0.025996
# Target                                            -0.016925
#
#                                                 Mother's qualification  \
# Marital status                                                0.189513
# Application mode                                              0.122954
# Application order                                            -0.061478
# Course                                                        0.056952
# Daytime/evening attendance\t                                 -0.208087
# Previous qualification                                       -0.022877
# Previous qualification (grade)                               -0.066329
# Nationality                                                  -0.056017
# Mother's qualification                                        1.000000
# Father's qualification                                        0.547487
# Mother's occupation                                           0.095697
# Father's occupation                                           0.075253
# Admission grade                                              -0.063444
# Displaced                                                    -0.083016
# Educational special needs                                    -0.015946
# Debtor                                                        0.037465
# Tuition fees up to date                                      -0.027038
# Gender                                                       -0.067935
# Scholarship holder                                            0.033987
# Age at enrollment                                             0.298557
# International                                                -0.045072
# Curricular units 1st sem (credited)                           0.043917
# Curricular units 1st sem (enrolled)                           0.040290
# Curricular units 1st sem (evaluations)                        0.041619
# Curricular units 1st sem (approved)                          -0.019708
# Curricular units 1st sem (grade)                             -0.036220
# Curricular units 1st sem (without evaluations)               -0.009661
# Curricular units 2nd sem (credited)                           0.043525
# Curricular units 2nd sem (enrolled)                           0.022323
# Curricular units 2nd sem (evaluations)                        0.019598
# Curricular units 2nd sem (approved)                          -0.022798
# Curricular units 2nd sem (grade)                             -0.025279
# Curricular units 2nd sem (without evaluations)                0.029154
# Unemployment rate                                            -0.122502
# Inflation rate                                                0.068868
# GDP                                                          -0.063152
# Target                                                       -0.068866
#
#                                                 Father's qualification  ...  \
# Marital status                                                0.130368  ...
# Application mode                                              0.077041  ...
# Application order                                            -0.052621  ...
# Course                                                        0.061807  ...
# Daytime/evening attendance\t                                 -0.147160  ...
# Previous qualification                                       -0.009386  ...
# Previous qualification (grade)                               -0.031867  ...
# Nationality                                                  -0.093294  ...
# Mother's qualification                                        0.547487  ...
# Father's qualification                                        1.000000  ...
# Mother's occupation                                           0.065795  ...
# Father's occupation                                           0.075835  ...
# Admission grade                                              -0.053138  ...
# Displaced                                                    -0.066554  ...
# Educational special needs                                    -0.006523  ...
# Debtor                                                       -0.000241  ...
# Tuition fees up to date                                      -0.001402  ...
# Gender                                                       -0.086019  ...
# Scholarship holder                                            0.107174  ...
# Age at enrollment                                             0.199205  ...
# International                                                -0.093436  ...
# Curricular units 1st sem (credited)                           0.033821  ...
# Curricular units 1st sem (enrolled)                           0.029563  ...
# Curricular units 1st sem (evaluations)                        0.039670  ...
# Curricular units 1st sem (approved)                           0.001098  ...
# Curricular units 1st sem (grade)                             -0.008574  ...
# Curricular units 1st sem (without evaluations)               -0.019186  ...
# Curricular units 2nd sem (credited)                           0.042725  ...
# Curricular units 2nd sem (enrolled)                           0.016883  ...
# Curricular units 2nd sem (evaluations)                        0.004979  ...
# Curricular units 2nd sem (approved)                           0.002307  ...
# Curricular units 2nd sem (grade)                             -0.009732  ...
# Curricular units 2nd sem (without evaluations)                0.003349  ...
# Unemployment rate                                            -0.086159  ...
# Inflation rate                                                0.066479  ...
# GDP                                                          -0.053712  ...
# Target                                                       -0.008850  ...
#
#                                                 Curricular units 2nd sem (credited)  \
# Marital status                                                             0.084395
# Application mode                                                           0.243542
# Application order                                                         -0.131017
# Course                                                                    -0.078812
# Daytime/evening attendance\t                                              -0.122959
# Previous qualification                                                     0.160649
# Previous qualification (grade)                                            -0.026858
# Nationality                                                               -0.004215
# Mother's qualification                                                     0.043525
# Father's qualification                                                     0.042725
# Mother's occupation                                                        0.008967
# Father's occupation                                                       -0.006256
# Admission grade                                                            0.028591
# Displaced                                                                 -0.093942
# Educational special needs                                                 -0.020630
# Debtor                                                                     0.025225
# Tuition fees up to date                                                   -0.002750
# Gender                                                                     0.003292
# Scholarship holder                                                        -0.086776
# Age at enrollment                                                          0.211933
# International                                                              0.006743
# Curricular units 1st sem (credited)                                        0.945763
# Curricular units 1st sem (enrolled)                                        0.753101
# Curricular units 1st sem (evaluations)                                     0.526627
# Curricular units 1st sem (approved)                                        0.604641
# Curricular units 1st sem (grade)                                           0.115850
# Curricular units 1st sem (without evaluations)                             0.097214
# Curricular units 2nd sem (credited)                                        1.000000
# Curricular units 2nd sem (enrolled)                                        0.667879
# Curricular units 2nd sem (evaluations)                                     0.431824
# Curricular units 2nd sem (approved)                                        0.512468
# Curricular units 2nd sem (grade)                                           0.132667
# Curricular units 2nd sem (without evaluations)                             0.050895
# Unemployment rate                                                          0.010701
# Inflation rate                                                             0.014956
# GDP                                                                       -0.032304
# Target                                                                     0.038414
#
#                                                 Curricular units 2nd sem (enrolled)  \
# Marital status                                                             0.051795
# Application mode                                                           0.132125
# Application order                                                          0.028622
# Course                                                                     0.410487
# Daytime/evening attendance\t                                               0.002892
# Previous qualification                                                     0.071322
# Previous qualification (grade)                                            -0.022924
# Nationality                                                               -0.008834
# Mother's qualification                                                     0.022323
# Father's qualification                                                     0.016883
# Mother's occupation                                                        0.004167
# Father's occupation                                                       -0.007874
# Admission grade                                                           -0.049817
# Displaced                                                                 -0.038953
# Educational special needs                                                 -0.010882
# Debtor                                                                    -0.028735
# Tuition fees up to date                                                    0.080373
# Gender                                                                    -0.140021
# Scholarship holder                                                         0.036242
# Age at enrollment                                                          0.081076
# International                                                             -0.008101
# Curricular units 1st sem (credited)                                        0.638030
# Curricular units 1st sem (enrolled)                                        0.941381
# Curricular units 1st sem (evaluations)                                     0.609275
# Curricular units 1st sem (approved)                                        0.736509
# Curricular units 1st sem (grade)                                           0.409680
# Curricular units 1st sem (without evaluations)                             0.084545
# Curricular units 2nd sem (credited)                                        0.667879
# Curricular units 2nd sem (enrolled)                                        1.000000
# Curricular units 2nd sem (evaluations)                                     0.613200
# Curricular units 2nd sem (approved)                                        0.705176
# Curricular units 2nd sem (grade)                                           0.402012
# Curricular units 2nd sem (without evaluations)                             0.042052
# Unemployment rate                                                          0.065623
# Inflation rate                                                             0.006179
# GDP                                                                       -0.017700
# Target                                                                     0.168748
#
#                                                 Curricular units 2nd sem (evaluations)  \
# Marital status                                                                0.035497
# Application mode                                                              0.165229
# Application order                                                            -0.052013
# Course                                                                        0.283521
# Daytime/evening attendance\t                                                  0.016528
# Previous qualification                                                        0.117448
# Previous qualification (grade)                                               -0.072581
# Nationality                                                                  -0.026081
# Mother's qualification                                                        0.019598
# Father's qualification                                                        0.004979
# Mother's occupation                                                           0.008152
# Father's occupation                                                           0.002384
# Admission grade                                                              -0.083880
# Displaced                                                                    -0.027388
# Educational special needs                                                    -0.010964
# Debtor                                                                        0.025491
# Tuition fees up to date                                                       0.066104
# Gender                                                                       -0.046196
# Scholarship holder                                                           -0.016479
# Age at enrollment                                                             0.061448
# International                                                                -0.007734
# Curricular units 1st sem (credited)                                           0.431915
# Curricular units 1st sem (enrolled)                                           0.605842
# Curricular units 1st sem (evaluations)                                        0.778131
# Curricular units 1st sem (approved)                                           0.549306
# Curricular units 1st sem (grade)                                              0.490515
# Curricular units 1st sem (without evaluations)                                0.126418
# Curricular units 2nd sem (credited)                                           0.431824
# Curricular units 2nd sem (enrolled)                                           0.613200
# Curricular units 2nd sem (evaluations)                                        1.000000
# Curricular units 2nd sem (approved)                                           0.468853
# Curricular units 2nd sem (grade)                                              0.455151
# Curricular units 2nd sem (without evaluations)                                0.135064
# Unemployment rate                                                             0.035747
# Inflation rate                                                               -0.023689
# GDP                                                                          -0.015058
# Target                                                                        0.083302
#
#                                                 Curricular units 2nd sem (approved)  \
# Marital status                                                            -0.030361
# Application mode                                                          -0.059697
# Application order                                                          0.062975
# Course                                                                     0.197997
# Daytime/evening attendance\t                                               0.031481
# Previous qualification                                                     0.011343
# Previous qualification (grade)                                             0.053421
# Nationality                                                               -0.011743
# Mother's qualification                                                    -0.022798
# Father's qualification                                                     0.002307
# Mother's occupation                                                       -0.019628
# Father's occupation                                                       -0.020918
# Admission grade                                                            0.068982
# Displaced                                                                  0.063589
# Educational special needs                                                 -0.012575
# Debtor                                                                    -0.144617
# Tuition fees up to date                                                    0.293870
# Gender                                                                    -0.227950
# Scholarship holder                                                         0.209188
# Age at enrollment                                                         -0.106844
# International                                                             -0.006713
# Curricular units 1st sem (credited)                                        0.486208
# Curricular units 1st sem (enrolled)                                        0.673720
# Curricular units 1st sem (evaluations)                                     0.437944
# Curricular units 1st sem (approved)                                        0.907976
# Curricular units 1st sem (grade)                                           0.677681
# Curricular units 1st sem (without evaluations)                            -0.028578
# Curricular units 2nd sem (credited)                                        0.512468
# Curricular units 2nd sem (enrolled)                                        0.705176
# Curricular units 2nd sem (evaluations)                                     0.468853
# Curricular units 2nd sem (approved)                                        1.000000
# Curricular units 2nd sem (grade)                                           0.765375
# Curricular units 2nd sem (without evaluations)                            -0.081786
# Unemployment rate                                                          0.050191
# Inflation rate                                                            -0.030144
# GDP                                                                        0.018909
# Target                                                                     0.622057
#
#                                                 Curricular units 2nd sem (grade)  \
# Marital status                                                         -0.063332
# Application mode                                                       -0.114381
# Application order                                                       0.050573
# Course                                                                  0.342332
# Daytime/evening attendance\t                                            0.050043
# Previous qualification                                                  0.004724
# Previous qualification (grade)                                          0.059821
# Nationality                                                             0.003051
# Mother's qualification                                                 -0.025279
# Father's qualification                                                 -0.009732
# Mother's occupation                                                    -0.012528
# Father's occupation                                                    -0.009475
# Admission grade                                                         0.073163
# Displaced                                                               0.071564
# Educational special needs                                              -0.007157
# Debtor                                                                 -0.139478
# Tuition fees up to date                                                 0.299395
# Gender                                                                 -0.199579
# Scholarship holder                                                      0.189068
# Age at enrollment                                                      -0.169832
# International                                                           0.007523
# Curricular units 1st sem (credited)                                     0.137026
# Curricular units 1st sem (enrolled)                                     0.368386
# Curricular units 1st sem (evaluations)                                  0.356921
# Curricular units 1st sem (approved)                                     0.690361
# Curricular units 1st sem (grade)                                        0.838460
# Curricular units 1st sem (without evaluations)                         -0.062251
# Curricular units 2nd sem (credited)                                     0.132667
# Curricular units 2nd sem (enrolled)                                     0.402012
# Curricular units 2nd sem (evaluations)                                  0.455151
# Curricular units 2nd sem (approved)                                     0.765375
# Curricular units 2nd sem (grade)                                        1.000000
# Curricular units 2nd sem (without evaluations)                         -0.085441
# Unemployment rate                                                      -0.010123
# Inflation rate                                                         -0.036388
# GDP                                                                     0.067280
# Target                                                                  0.564461
#
#                                                 Curricular units 2nd sem (without evaluations)  \
# Marital status                                                                        0.027758
# Application mode                                                                      0.037492
# Application order                                                                    -0.020588
# Course                                                                                0.035514
# Daytime/evening attendance\t                                                         -0.020200
# Previous qualification                                                               -0.003203
# Previous qualification (grade)                                                       -0.020381
# Nationality                                                                          -0.011046
# Mother's qualification                                                                0.029154
# Father's qualification                                                                0.003349
# Mother's occupation                                                                   0.026021
# Father's occupation                                                                   0.005715
# Admission grade                                                                      -0.011223
# Displaced                                                                            -0.034931
# Educational special needs                                                            -0.014701
# Debtor                                                                                0.043717
# Tuition fees up to date                                                              -0.056446
# Gender                                                                                0.063611
# Scholarship holder                                                                   -0.038861
# Age at enrollment                                                                     0.064276
# International                                                                        -0.007762
# Curricular units 1st sem (credited)                                                   0.039749
# Curricular units 1st sem (enrolled)                                                   0.049386
# Curricular units 1st sem (evaluations)                                                0.125815
# Curricular units 1st sem (approved)                                                  -0.068286
# Curricular units 1st sem (grade)                                                     -0.076759
# Curricular units 1st sem (without evaluations)                                        0.552219
# Curricular units 2nd sem (credited)                                                   0.050895
# Curricular units 2nd sem (enrolled)                                                   0.042052
# Curricular units 2nd sem (evaluations)                                                0.135064
# Curricular units 2nd sem (approved)                                                  -0.081786
# Curricular units 2nd sem (grade)                                                     -0.085441
# Curricular units 2nd sem (without evaluations)                                        1.000000
# Unemployment rate                                                                     0.002914
# Inflation rate                                                                       -0.042602
# GDP                                                                                  -0.101726
# Target                                                                               -0.096342
#
#                                                 Unemployment rate  \
# Marital status                                          -0.027686
# Application mode                                         0.075775
# Application order                                       -0.080164
# Course                                                   0.018721
# Daytime/evening attendance\t                             0.050563
# Previous qualification                                   0.101522
# Previous qualification (grade)                           0.040532
# Nationality                                              0.001012
# Mother's qualification                                  -0.122502
# Father's qualification                                  -0.086159
# Mother's occupation                                     -0.085626
# Father's occupation                                     -0.094316
# Admission grade                                          0.034567
# Displaced                                               -0.112718
# Educational special needs                                0.039444
# Debtor                                                   0.018556
# Tuition fees up to date                                  0.016238
# Gender                                                   0.016867
# Scholarship holder                                       0.051791
# Age at enrollment                                        0.021097
# International                                           -0.007224
# Curricular units 1st sem (credited)                      0.007316
# Curricular units 1st sem (enrolled)                      0.037438
# Curricular units 1st sem (evaluations)                   0.046240
# Curricular units 1st sem (approved)                      0.053920
# Curricular units 1st sem (grade)                         0.008510
# Curricular units 1st sem (without evaluations)          -0.042600
# Curricular units 2nd sem (credited)                      0.010701
# Curricular units 2nd sem (enrolled)                      0.065623
# Curricular units 2nd sem (evaluations)                   0.035747
# Curricular units 2nd sem (approved)                      0.050191
# Curricular units 2nd sem (grade)                        -0.010123
# Curricular units 2nd sem (without evaluations)           0.002914
# Unemployment rate                                        1.000000
# Inflation rate                                          -0.032581
# GDP                                                     -0.332225
# Target                                                   0.017947
#
#                                                 Inflation rate       GDP  \
# Marital status                                        0.004827 -0.012190
# Application mode                                     -0.020523 -0.015862
# Application order                                    -0.007269  0.019101
# Course                                                0.008311 -0.041427
# Daytime/evening attendance\t                         -0.029515  0.016956
# Previous qualification                               -0.055605  0.072228
# Previous qualification (grade)                        0.017046 -0.048740
# Nationality                                          -0.008991  0.025996
# Mother's qualification                                0.068868 -0.063152
# Father's qualification                                0.066479 -0.053712
# Mother's occupation                                   0.020267  0.115285
# Father's occupation                                   0.026089  0.122792
# Admission grade                                      -0.008769 -0.026825
# Displaced                                            -0.003521  0.055957
# Educational special needs                             0.015021  0.010773
# Debtor                                               -0.030816  0.072335
# Tuition fees up to date                               0.002250 -0.009102
# Gender                                               -0.001561  0.005765
# Scholarship holder                                   -0.018339  0.037938
# Age at enrollment                                     0.027322 -0.055473
# International                                        -0.002490  0.030860
# Curricular units 1st sem (credited)                   0.020229 -0.025924
# Curricular units 1st sem (enrolled)                   0.025854 -0.032287
# Curricular units 1st sem (evaluations)               -0.012435 -0.109926
# Curricular units 1st sem (approved)                  -0.015670  0.015355
# Curricular units 1st sem (grade)                     -0.038226  0.038402
# Curricular units 1st sem (without evaluations)       -0.062558 -0.159280
# Curricular units 2nd sem (credited)                   0.014956 -0.032304
# Curricular units 2nd sem (enrolled)                   0.006179 -0.017700
# Curricular units 2nd sem (evaluations)               -0.023689 -0.015058
# Curricular units 2nd sem (approved)                  -0.030144  0.018909
# Curricular units 2nd sem (grade)                     -0.036388  0.067280
# Curricular units 2nd sem (without evaluations)       -0.042602 -0.101726
# Unemployment rate                                    -0.032581 -0.332225
# Inflation rate                                        1.000000 -0.108234
# GDP                                                  -0.108234  1.000000
# Target                                               -0.033589  0.042484
#
#                                                   Target
# Marital status                                 -0.087741
# Application mode                               -0.209867
# Application order                               0.088745
# Course                                          0.020586
# Daytime/evening attendance\t                    0.087208
# Previous qualification                         -0.053785
# Previous qualification (grade)                  0.111464
# Nationality                                    -0.016925
# Mother's qualification                         -0.068866
# Father's qualification                         -0.008850
# Mother's occupation                            -0.000953
# Father's occupation                             0.002801
# Admission grade                                 0.119904
# Displaced                                       0.117679
# Educational special needs                      -0.000011
# Debtor                                         -0.237070
# Tuition fees up to date                         0.416535
# Gender                                         -0.234719
# Scholarship holder                              0.315446
# Age at enrollment                              -0.256159
# International                                   0.003332
# Curricular units 1st sem (credited)             0.030178
# Curricular units 1st sem (enrolled)             0.142279
# Curricular units 1st sem (evaluations)          0.033549
# Curricular units 1st sem (approved)             0.520674
# Curricular units 1st sem (grade)                0.483273
# Curricular units 1st sem (without evaluations) -0.067649
# Curricular units 2nd sem (credited)             0.038414
# Curricular units 2nd sem (enrolled)             0.168748
# Curricular units 2nd sem (evaluations)          0.083302
# Curricular units 2nd sem (approved)             0.622057
# Curricular units 2nd sem (grade)                0.564461
# Curricular units 2nd sem (without evaluations) -0.096342
# Unemployment rate                               0.017947
# Inflation rate                                 -0.033589
# GDP                                             0.042484
# Target                                          1.000000
#
# [37 rows x 37 columns]

# %%
train_corrmat = train.corr()

k=20
cols = train_corrmat.nlargest(k,"Target")["Target"].index
cm = train_corrmat[cols].loc[cols]

plt.figure(figsize = (36,36))
sns.set(font_scale=3)
heatmap = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 18}, yticklabels=cols.values, xticklabels=cols.values)
heatmap.set_title('Correlation Matrix', fontdict={'fontsize':18}, pad=12);
# Out:
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# D:\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
sns.set()

cols = ['Target','Curricular units 1st sem (approved)', 'Curricular units 1st sem (grade)', 'Curricular units 2nd sem (approved)', 'Curricular units 2nd sem (grade)','Tuition fees up to date']
sns.pairplot(train[cols], height = 2.5)
plt.show()

# %% [markdown]
# # SelectKBest

# %%
from sklearn.feature_selection import SelectKBest, chi2

# %%
X_new = SelectKBest(chi2,k=20).fit_transform(X_train,y_train)
print(X_new)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-28c4ebfed225> in <module>
# ----> 1 X_new = SelectKBest(chi2,k=20).fit_transform(X_train,y_train)
#       2 print(X_new)
#
# ~\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     853         else:
#     854             # fit method of arity 2 (supervised transformation)
# --> 855             return self.fit(X, y, **fit_params).transform(X)
#     856
#     857
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py in fit(self, X, y)
#     406
#     407         self._check_params(X, y)
# --> 408         score_func_ret = self.score_func(X, y)
#     409         if isinstance(score_func_ret, (list, tuple)):
#     410             self.scores_, self.pvalues_ = score_func_ret
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_selection\_univariate_selection.py in chi2(X, y)
#     213     X = check_array(X, accept_sparse="csr")
#     214     if np.any((X.data if issparse(X) else X) < 0):
# --> 215         raise ValueError("Input X must be non-negative.")
#     216
#     217     Y = LabelBinarizer().fit_transform(y)
#
# ValueError: Input X must be non-negative.

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_val_score

# %%
svm = make_pipeline(StandardScaler(),SVC(kernel = 'linear',random_state=0))

# %%
y = np.array(train['Target'])
X = np.array(train.drop('Target',axis=1))
X_train, X_valid, y_train,y_valid = train_test_split(X,y,test_size = 0.33, random_state=42)

# %%
X_test = test.drop(columns="StudentId")

# %% [markdown]
# Train/Validation result

# %%
svm.fit(X_train,y_train)
y_pred = svm.predict(X_valid)

# %%
print(classification_report(y_valid, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.71      0.76       306
#            1       0.47      0.35      0.40       184
#            2       0.81      0.93      0.87       532
#
#     accuracy                           0.76      1022
#    macro avg       0.70      0.67      0.68      1022
# weighted avg       0.75      0.76      0.75      1022

# %% [markdown]
# Cross Validation Result

# %%
cross_scores = cross_val_score(svm,X,y,cv=5,scoring="f1_weighted")

# %%
print(cross_scores)
print(np.mean(cross_scores))
# Out:
# [0.77360554 0.79339425 0.73567143 0.73802033 0.76197217]
# 0.760532745178692

# %%
svm_dataframe = pd.DataFrame({"Target" : label_enco.inverse_transform(svm.predict(X_test))})
svm_dataframe["StudentId"] = test["StudentId"]
svm_dataframe = svm_dataframe.iloc[:, ::-1]
print(svm_dataframe)
# Out:
#       StudentId    Target
# 0          3097  Graduate
# 1          3098  Graduate
# 2          3099  Graduate
# 3          3100  Graduate
# 4          3101  Enrolled
# ...         ...       ...
# 1323       4420  Graduate
# 1324       4421   Dropout
# 1325       4422  Enrolled
# 1326       4423   Dropout
# 1327       4424  Graduate
#
# [1328 rows x 2 columns]

# %%
svm_dataframe.to_csv("predictions/svm_prediction.csv",index=False)

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier

# %%
params = {"n_estimators": [10,70,80,90,100,120,150,200,250,280,300],
        "max_features":[0.3,0.4,0.5,0.6,0.8,1]}

cv = 5
random_Forest = RandomForestClassifier(random_state=42)
forest_cv = GridSearchCV(random_Forest,params,scoring='f1_weighted',cv=cv,verbose=1,n_jobs=4)
forest_cv.fit(X_train,y_train)

score = forest_cv.score(X_valid,y_valid)
print('Random forest: {:.2f}'.format(score))
print('-----')
print('Best hyper-params: ' + str(forest_cv.best_params_))
# Out:
# Fitting 5 folds for each of 66 candidates, totalling 330 fits
# Random forest: 0.76
# -----
# Best hyper-params: {'max_features': 0.5, 'n_estimators': 90}

# %%
final_random_Forest = RandomForestClassifier(random_state=42,max_features=0.5,n_estimators=90)
final_random_Forest.fit(X_train,y_train)
forest_dataframe = pd.DataFrame({"Target" : label_enco.inverse_transform(final_random_Forest.predict(X_test))})
forest_dataframe["StudentId"] = test["StudentId"]
forest_dataframe = forest_dataframe.iloc[:, ::-1]
print(forest_dataframe)
# Out:
#       StudentId    Target
# 0          3097  Graduate
# 1          3098  Graduate
# 2          3099  Graduate
# 3          3100  Graduate
# 4          3101  Enrolled
# ...         ...       ...
# 1323       4420  Graduate
# 1324       4421   Dropout
# 1325       4422  Graduate
# 1326       4423   Dropout
# 1327       4424  Graduate
#
# [1328 rows x 2 columns]

# %%
forest_dataframe.to_csv("./predictions/forest_prediction.csv",index=False)

# %% [markdown]
# # Gradient Boosting

# %%
gradient_params = {"learning_rate" : [0.001, 0.01, 0.1],
             "max_depth": [1, 2, 3, 4, 5],
             'min_samples_leaf': [10, 30, 60, 90, 120],
             'min_samples_split': [30, 60, 90, 120],
             "subsample": [	0.2, 0.4, 0.6, 0.8, 1]}



gradient_model = GradientBoostingClassifier(n_estimators=90)
gradient_gridSearch = GridSearchCV(gradient_model,gradient_params,cv=cv,verbose=1,n_jobs=4)
gradient_gridSearch.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 1500 candidates, totalling 7500 fits
# GridSearchCV(cv=5, estimator=GradientBoostingClassifier(n_estimators=90),
#              n_jobs=4,
#              param_grid={'learning_rate': [0.001, 0.01, 0.1],
#                          'max_depth': [1, 2, 3, 4, 5],
#                          'min_samples_leaf': [10, 30, 60, 90, 120],
#                          'min_samples_split': [30, 60, 90, 120],
#                          'subsample': [0.2, 0.4, 0.6, 0.8, 1]},
#              verbose=1)

# %%
print('Best hyperparameters: ' + str(gradient_gridSearch.best_params_))
# Out:
# Best hyperparameters: {'learning_rate': 0.1, 'max_depth': 4, 'min_samples_leaf': 120, 'min_samples_split': 60, 'subsample': 0.8}

# %%
final_gradient_model = GradientBoostingClassifier(n_estimators=90,learning_rate=0.1,max_depth=4,min_samples_leaf=120,min_samples_split=60,subsample=0.8)
gradient_cross_scores = cross_val_score(final_gradient_model,X,y,cv=5,scoring="f1_weighted")

# %%
print(gradient_cross_scores)
# Out:
# [0.77475201 0.75455368 0.75869761 0.73866528 0.7476152 ]

# %%
print(gradient_cross_scores)
print(np.mean(gradient_cross_scores))
# Out:
# [0.77475201 0.75455368 0.75869761 0.73866528 0.7476152 ]
# 0.7548567562386741

# %%
final_gradient_model.fit(X_train,y_train)
gradient_dataframe = pd.DataFrame({"Target" : label_enco.inverse_transform(final_gradient_model.predict(X_test))})
gradient_dataframe["StudentId"] = test["StudentId"]
gradient_dataframe = gradient_dataframe.iloc[:, ::-1]
print(gradient_dataframe)
# Out:
#       StudentId    Target
# 0          3097  Graduate
# 1          3098  Graduate
# 2          3099  Graduate
# 3          3100  Graduate
# 4          3101  Enrolled
# ...         ...       ...
# 1323       4420  Graduate
# 1324       4421   Dropout
# 1325       4422  Enrolled
# 1326       4423   Dropout
# 1327       4424  Graduate
#
# [1328 rows x 2 columns]

# %%
gradient_dataframe.to_csv("./predictions/gradient_prediction.csv",index=False)

# %% [markdown]
# # Stacking

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import StackingClassifier

# %%
models = [('Random Forest', RandomForestClassifier(random_state=42,max_features=0.5,n_estimators=90)),
         ('Gradient Booster', GradientBoostingClassifier(n_estimators=90,learning_rate=0.1,max_depth=4,min_samples_leaf=120,min_samples_split=60,subsample=0.8)),
         ('SVM' , make_pipeline(StandardScaler(),SVC(kernel = 'linear',random_state=0)))]
#,('SVM' , make_pipeline(StandardScaler(),SVC(kernel = 'linear',random_state=0)))
stacking = StackingClassifier(models,final_estimator = LogisticRegression(),cv=5,n_jobs = 4,passthrough = False,verbose = 1 )
stacking.fit(X_train,y_train)
stacking_score = stacking.score(X_valid,y_valid)
print(stacking_score)
# Out:
# 0.7583170254403131

# %%
stacking_dataframe = pd.DataFrame({"Target" : label_enco.inverse_transform(stacking.predict(X_test))})
stacking_dataframe["StudentId"] = test["StudentId"]
stacking_dataframe = stacking_dataframe.iloc[:, ::-1]
print(stacking_dataframe)
# Out:
#       StudentId    Target
# 0          3097  Graduate
# 1          3098  Graduate
# 2          3099  Graduate
# 3          3100  Graduate
# 4          3101  Enrolled
# ...         ...       ...
# 1323       4420  Graduate
# 1324       4421   Dropout
# 1325       4422  Enrolled
# 1326       4423   Dropout
# 1327       4424  Graduate
#
# [1328 rows x 2 columns]
# C:\Users\basti\Anaconda3\lib\site-packages\sklearn\base.py:444: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"
# C:\Users\basti\Anaconda3\lib\site-packages\sklearn\base.py:444: UserWarning: X has feature names, but GradientBoostingClassifier was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"

# %%
stacking_dataframe.to_csv("./predictions/stacking_prediction.csv",index=False)
